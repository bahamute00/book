# %% [markdown]
# <a href="https://colab.research.google.com/github/bahamute00/book/blob/master/01%EC%9D%BC%EC%B0%A8_%EC%8B%A4%EC%8A%B5%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. yfinance를 설치해서 "주가"데이터 가져오기

# %% [markdown]
# ### 1. 야후파이낸스 라이브러리 실행

# %%
import yfinance as yf

# %% [markdown]
# ### 2. 그래프 및 데이터프레임(엑셀형식의 데이터 작성) 지원 라이브러리 실행

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 3. 데이터를 받아오는 코드

# %%
# 페이팔 주식 데이터를 가져옵니다.
start_date = '2015-09-01'
end_date = '2024-06-18'
ticker = 'PYPL'
data_pypl = yf.download(ticker, start=start_date, end=end_date)

# 데이터프레임으로 변환합니다.
df_pypl = pd.DataFrame(data_pypl['Close'])
df_pypl.columns = [ticker + 'price']
df_pypl.index.name = 'date'

# 시작일 이후의 데이터만 필터링합니다.
df_pypl = df_pypl[df_pypl.index >= '2015-09-01']


# 기준 금리 데이터 : 미리보기
df_pypl
# Out:
# [*********************100%%**********************]  1 of 1 completed
#             PYPLprice
# date
# 2015-09-01  33.770000
# 2015-09-02  35.070000
# 2015-09-03  35.310001
# 2015-09-04  34.290001
# 2015-09-08  34.700001
# ...               ...
# 2024-06-11  64.769997
# 2024-06-12  63.430000
# 2024-06-13  61.540001
# 2024-06-14  60.634998
# 2024-06-17  60.130001
#
# [2213 rows x 1 columns]

# %%
data_pypl
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# date
# 2015-09-01  34.150002  34.680000  33.410000  33.770000  33.770000  13376000
# 2015-09-02  34.599998  35.080002  33.834999  35.070000  35.070000   7521000
# 2015-09-03  35.009998  35.459999  34.770000  35.310001  35.310001   6683800
# 2015-09-04  34.709999  34.720001  33.779999  34.290001  34.290001   7483100
# 2015-09-08  34.810001  34.889999  34.250000  34.700001  34.700001   7674500
# ...               ...        ...        ...        ...        ...       ...
# 2024-06-11  67.129997  67.150002  64.404999  64.769997  64.769997  15108700
# 2024-06-12  65.459999  65.860001  62.900002  63.430000  63.430000  14137500
# 2024-06-13  63.119999  63.625000  61.520000  61.540001  61.540001  11985400
# 2024-06-14  61.290001  61.639999  60.310001  60.634998  60.634998  10366000
# 2024-06-17  60.369999  60.639999  59.480999  60.130001  60.130001  13558500
#
# [2213 rows x 6 columns]

# %% [markdown]
# (참고 데이터프레임)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 페이팔 데이터 출력
print(df_pypl)
# Out:
#             PYPLprice
# date
# 2015-09-01  33.770000
# 2015-09-02  35.070000
# 2015-09-03  35.310001
# 2015-09-04  34.290001
# 2015-09-08  34.700001
# ...               ...
# 2024-06-11  64.769997
# 2024-06-12  63.430000
# 2024-06-13  61.540001
# 2024-06-14  60.634998
# 2024-06-17  60.130001
#
# [2213 rows x 1 columns]

# %% [markdown]
# ### 4. 데이터를 저장하는 코드

# %%
# 페이팔 주가 데이터를 CSV 파일로 저장

# CSV 파일로 저장
from google.colab import files

df_pypl.to_csv('pypl.csv', encoding='utf-8-sig')

# 파일을 다운로드합니다.
files.download('pypl.csv')

# %% [markdown]
# ###5. 차트를 그려주는 코드

# %%
# 차트(그래프) 작성
plt.figure(figsize=(10, 6))
plt.plot(df_pypl)
plt.title(ticker + ' price')
plt.xlabel('date')
plt.ylabel('price')
plt.grid(True)
plt.show()

# %% [markdown]
# 과제 : S&P500(SPY), 어펌(AFRM), 아마존(AMZN)의 주가데이터를 받아오는 코드를 작성
# : MSFT

# %% [markdown]
# ###(과제1) S&P500(SPY)

# %%
#작업에 필요한 라이브러리(데이터 받기, 데이터 포멧변경, 그래프 작성)
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 주식 데이터를 가져옵니다.
start_date = '2015-09-01'
end_date = '2023-06-30'
ticker = 'SPY' #티커는 대문자
data_spy = yf.download(ticker, start=start_date, end=end_date)

# 데이터프레임으로 변환합니다.
df_spy = pd.DataFrame(data_spy['Close'])
df_spy.columns = [ticker + 'price']
df_spy.index.name = 'date'

# 시작일 이후의 데이터만 필터링합니다.
df_spy = df_spy[df_spy.index >= '2015-09-01']


# 기준 금리 데이터 : 미리보기
df_spy
# Out:
# [*********************100%***********************]  1 of 1 completed
#               SPYprice
# date
# 2015-09-01  191.770004
# 2015-09-02  195.410004
# 2015-09-03  195.550003
# 2015-09-04  192.589996
# 2015-09-08  197.429993
# ...                ...
# 2023-06-23  433.209991
# 2023-06-26  431.440002
# 2023-06-27  436.170013
# 2023-06-28  436.390015
# 2023-06-29  438.109985
#
# [1970 rows x 1 columns]

# %%
# 주가 데이터를 CSV 파일로 저장

# CSV 파일로 저장
from google.colab import files

df_spy.to_csv('spy.csv', encoding='utf-8-sig')

# 파일을 다운로드합니다.
files.download('spy.csv')

# %%
# 차트(그래프) 작성
plt.figure(figsize=(10, 6))
plt.plot(df_spy)
plt.title(ticker + ' price')
plt.xlabel('date')
plt.ylabel('price')
plt.grid(True)
plt.show()

# %% [markdown]
# ###(과제2) affirm(AFRM) /BNPL Buy Now Pay Later
